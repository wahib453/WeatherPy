# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests as req

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f5ad8758e4c5d9f272f9c5d4b8f8376e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 100 for logging purposes.
    if (i % 100 == 0 and i >= 100):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | vilyuysk
# Processing Record 3 of Set 1 | pangnirtung
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | swan hill
# Processing Record 7 of Set 1 | kostomuksha
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | kruisfontein
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | coihaique
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | fort nelson
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | tukrah
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | poum
# Processing Record 29 of Set 1 | burnie
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | dudinka
# Processing Record 32 of Set 1 | chumikan
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | beira
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | asau
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | puerto del rosario
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | bongandanga
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | rocha
# Processing Record 48 of Set 1 | agadez
# Processing Record 49 of Set 1 | sangar
# Processing Record 50 of Set 1 | beloha
# Processing Record 51 of Set 1 | atuona
# Processing Record 52 of Set 1 | butaritari
# Processing Record 53 of Set 1 | new norfolk
# Processing Record 54 of Set 1 | usinsk
# Processing Record 55 of Set 1 | kapaa
# Processing Record 56 of Set 1 | port alfred
# Processing Record 57 of Set 1 | kavieng
# Processing Record 58 of Set 1 | norman wells
# Processing Record 59 of Set 1 | vao
# Processing Record 60 of Set 1 | ribeira grande
# Processing Record 61 of Set 1 | mar del plata
# Processing Record 62 of Set 1 | yenagoa
# Processing Record 63 of Set 1 | chuy
# Processing Record 64 of Set 1 | hilo
# Processing Record 65 of Set 1 | dublin
# Processing Record 66 of Set 1 | nouadhibou
# Processing Record 67 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 68 of Set 1 | kodiak
# Processing Record 69 of Set 1 | lodja
# Processing Record 70 of Set 1 | walvis bay
# Processing Record 71 of Set 1 | fortuna
# Processing Record 72 of Set 1 | mahebourg
# Processing Record 73 of Set 1 | booue
# Processing Record 74 of Set 1 | trelew
# Processing Record 75 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 76 of Set 1 | ulan-ude
# Processing Record 77 of Set 1 | cape town
# Processing Record 78 of Set 1 | sitka
# Processing Record 79 of Set 1 | vaini
# Processing Record 80 of Set 1 | nikolskoye
# Processing Record 81 of Set 1 | ponta do sol
# Processing Record 82 of Set 1 | turtkul
# City not found. Skipping...
# Processing Record 83 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 84 of Set 1 | tuatapere
# Processing Record 85 of Set 1 | taman
# Processing Record 86 of Set 1 | marawi
# Processing Record 87 of Set 1 | baghmara
# Processing Record 88 of Set 1 | yichang
# Processing Record 89 of Set 1 | port-cartier
# Processing Record 90 of Set 1 | lagoa
# Processing Record 91 of Set 1 | mataura
# Processing Record 92 of Set 1 | upernavik
# Processing Record 93 of Set 1 | torbay
# Processing Record 94 of Set 1 | puerto escondido
# Processing Record 95 of Set 1 | faanui
# Processing Record 96 of Set 1 | kulhudhuffushi
# Processing Record 97 of Set 1 | calvinia
# Processing Record 98 of Set 1 | great yarmouth
# Processing Record 99 of Set 1 | bathsheba
# Processing Record 100 of Set 1 | lompoc
# Processing Record 1 of Set 2 | richards bay
# Processing Record 2 of Set 2 | kalino
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | baruun-urt
# Processing Record 5 of Set 2 | silveira
# Processing Record 6 of Set 2 | lima
# Processing Record 7 of Set 2 | ostrovnoy
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | yeppoon
# Processing Record 10 of Set 2 | bonthe
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | geraldton
# Processing Record 13 of Set 2 | duiwelskloof
# Processing Record 14 of Set 2 | sisimiut
# Processing Record 15 of Set 2 | arcachon
# Processing Record 16 of Set 2 | peniche
# Processing Record 17 of Set 2 | komsomolskiy
# Processing Record 18 of Set 2 | anchorage
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | sooke
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | bima
# Processing Record 26 of Set 2 | beringovskiy
# Processing Record 27 of Set 2 | khilok
# Processing Record 28 of Set 2 | saint george
# Processing Record 29 of Set 2 | touros
# Processing Record 30 of Set 2 | westport
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | atlantis
# Processing Record 33 of Set 2 | gao
# Processing Record 34 of Set 2 | turukhansk
# Processing Record 35 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 36 of Set 2 | port-gentil
# Processing Record 37 of Set 2 | port hardy
# Processing Record 38 of Set 2 | sao joao da barra
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | athabasca
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | marechal deodoro
# Processing Record 43 of Set 2 | anadyr
# Processing Record 44 of Set 2 | denpasar
# Processing Record 45 of Set 2 | morro bay
# Processing Record 46 of Set 2 | santiago
# Processing Record 47 of Set 2 | kattivakkam
# Processing Record 48 of Set 2 | nagato
# Processing Record 49 of Set 2 | kinkala
# Processing Record 50 of Set 2 | iranshahr
# Processing Record 51 of Set 2 | nanortalik
# Processing Record 52 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 53 of Set 2 | williston
# Processing Record 54 of Set 2 | asyut
# Processing Record 55 of Set 2 | wau
# Processing Record 56 of Set 2 | sioux lookout
# Processing Record 57 of Set 2 | muromtsevo
# Processing Record 58 of Set 2 | jaisalmer
# Processing Record 59 of Set 2 | rutana
# Processing Record 60 of Set 2 | price
# Processing Record 61 of Set 2 | korla
# Processing Record 62 of Set 2 | port elizabeth
# Processing Record 63 of Set 2 | grants
# Processing Record 64 of Set 2 | pacific grove
# Processing Record 65 of Set 2 | neuquen
# Processing Record 66 of Set 2 | shaartuz
# City not found. Skipping...
# Processing Record 67 of Set 2 | chimbote
# Processing Record 68 of Set 2 | kralendijk
# Processing Record 69 of Set 2 | itarema
# Processing Record 70 of Set 2 | sainte-maxime
# Processing Record 71 of Set 2 | kanadey
# Processing Record 72 of Set 2 | husavik
# Processing Record 73 of Set 2 | mount isa
# Processing Record 74 of Set 2 | encruzilhada do sul
# Processing Record 75 of Set 2 | vila franca do campo
# Processing Record 76 of Set 2 | hobyo
# Processing Record 77 of Set 2 | necochea
# Processing Record 78 of Set 2 | saint-pierre
# Processing Record 79 of Set 2 | constitucion
# Processing Record 80 of Set 2 | lucea
# Processing Record 81 of Set 2 | khatanga
# Processing Record 82 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 83 of Set 2 | corowa
# Processing Record 84 of Set 2 | vanavara
# Processing Record 85 of Set 2 | hualmay
# Processing Record 86 of Set 2 | boffa
# Processing Record 87 of Set 2 | chicama
# Processing Record 88 of Set 2 | san carlos de bariloche
# Processing Record 89 of Set 2 | makakilo city
# Processing Record 90 of Set 2 | yumen
# Processing Record 91 of Set 2 | cidreira
# Processing Record 92 of Set 2 | kismayo
# Processing Record 93 of Set 2 | hambantota
# Processing Record 94 of Set 2 | dwarka
# Processing Record 95 of Set 2 | brokopondo
# Processing Record 96 of Set 2 | vigrestad
# Processing Record 97 of Set 2 | acapulco
# Processing Record 98 of Set 2 | los llanos de aridane
# Processing Record 99 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 100 of Set 2 | cayenne
# Processing Record 1 of Set 3 | taranto
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | ostersund
# Processing Record 4 of Set 3 | liangxiang
# Processing Record 5 of Set 3 | terra rica
# Processing Record 6 of Set 3 | jilmah
# City not found. Skipping...
# Processing Record 7 of Set 3 | rawson
# Processing Record 8 of Set 3 | labytnangi
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | cherskiy
# Processing Record 11 of Set 3 | aklavik
# Processing Record 12 of Set 3 | tecoanapa
# Processing Record 13 of Set 3 | isla mujeres
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | the valley
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | boras
# Processing Record 18 of Set 3 | bandarbeyla
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | port moresby
# Processing Record 21 of Set 3 | qorveh
# Processing Record 22 of Set 3 | flin flon
# Processing Record 23 of Set 3 | buraydah
# Processing Record 24 of Set 3 | turinskaya sloboda
# Processing Record 25 of Set 3 | dalvik
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | san joaquin
# Processing Record 28 of Set 3 | faya
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | kloulklubed
# Processing Record 31 of Set 3 | roald
# Processing Record 32 of Set 3 | manggar
# Processing Record 33 of Set 3 | dumas
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | erzin
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | antalaha
# Processing Record 38 of Set 3 | la palma
# Processing Record 39 of Set 3 | copiapo
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | paamiut
# Processing Record 42 of Set 3 | shchuchye
# City not found. Skipping...
# Processing Record 43 of Set 3 | havre-saint-pierre
# Processing Record 44 of Set 3 | margate
# Processing Record 45 of Set 3 | telfs
# Processing Record 46 of Set 3 | nome
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | bintulu
# Processing Record 49 of Set 3 | koslan
# Processing Record 50 of Set 3 | pativilca
# Processing Record 51 of Set 3 | ishigaki
# Processing Record 52 of Set 3 | portland
# Processing Record 53 of Set 3 | fiditi
# Processing Record 54 of Set 3 | ulladulla
# Processing Record 55 of Set 3 | olinda
# Processing Record 56 of Set 3 | praya
# Processing Record 57 of Set 3 | winneba
# Processing Record 58 of Set 3 | owo
# Processing Record 59 of Set 3 | cabo san lucas
# Processing Record 60 of Set 3 | ahipara
# Processing Record 61 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 62 of Set 3 | mbandaka
# Processing Record 63 of Set 3 | svolvaer
# Processing Record 64 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 65 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 66 of Set 3 | lydenburg
# Processing Record 67 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 68 of Set 3 | kailua
# Processing Record 69 of Set 3 | bambous virieux
# Processing Record 70 of Set 3 | nyurba
# Processing Record 71 of Set 3 | maceio
# Processing Record 72 of Set 3 | poitiers
# Processing Record 73 of Set 3 | bukachacha
# Processing Record 74 of Set 3 | sheridan
# Processing Record 75 of Set 3 | padang
# Processing Record 76 of Set 3 | qaanaaq
# Processing Record 77 of Set 3 | marienburg
# Processing Record 78 of Set 3 | mayo
# Processing Record 79 of Set 3 | yar-sale
# Processing Record 80 of Set 3 | saint-philippe
# Processing Record 81 of Set 3 | sai buri
# Processing Record 82 of Set 3 | pontianak
# Processing Record 83 of Set 3 | taoudenni
# Processing Record 84 of Set 3 | leningradskiy
# Processing Record 85 of Set 3 | basco
# Processing Record 86 of Set 3 | kontagora
# Processing Record 87 of Set 3 | saldanha
# Processing Record 88 of Set 3 | kedarnath
# City not found. Skipping...
# Processing Record 89 of Set 3 | ust-kuyga
# Processing Record 90 of Set 3 | nishihara
# Processing Record 91 of Set 3 | labrea
# Processing Record 92 of Set 3 | aykhal
# Processing Record 93 of Set 3 | savino
# Processing Record 94 of Set 3 | coos bay
# Processing Record 95 of Set 3 | muros
# Processing Record 96 of Set 3 | mendoza
# Processing Record 97 of Set 3 | atambua
# Processing Record 98 of Set 3 | havelock
# Processing Record 99 of Set 3 | malkangiri
# Processing Record 100 of Set 3 | aras
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | bridlington
# Processing Record 6 of Set 4 | umm lajj
# Processing Record 7 of Set 4 | galveston
# Processing Record 8 of Set 4 | akom
# Processing Record 9 of Set 4 | beryslav
# Processing Record 10 of Set 4 | ayan
# Processing Record 11 of Set 4 | haines junction
# Processing Record 12 of Set 4 | poltavka
# Processing Record 13 of Set 4 | boa vista
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | mogadishu
# Processing Record 16 of Set 4 | shimoda
# Processing Record 17 of Set 4 | winnemucca
# Processing Record 18 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 4 | odweyne
# Processing Record 20 of Set 4 | hasaki
# Processing Record 21 of Set 4 | kabwe
# Processing Record 22 of Set 4 | bambanglipuro
# Processing Record 23 of Set 4 | lusambo
# Processing Record 24 of Set 4 | mildura
# Processing Record 25 of Set 4 | senges
# Processing Record 26 of Set 4 | henties bay
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | luxor
# Processing Record 30 of Set 4 | bajos de haina
# Processing Record 31 of Set 4 | assiniboia
# Processing Record 32 of Set 4 | honningsvag
# Processing Record 33 of Set 4 | kysyl-syr
# Processing Record 34 of Set 4 | ada
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | murgab
# Processing Record 37 of Set 4 | socorro
# Processing Record 38 of Set 4 | caravelas
# Processing Record 39 of Set 4 | saint-leu
# Processing Record 40 of Set 4 | diffa
# Processing Record 41 of Set 4 | palmer
# Processing Record 42 of Set 4 | nhulunbuy
# Processing Record 43 of Set 4 | lesnoy
# Processing Record 44 of Set 4 | vila do maio
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 4 | itaituba
# Processing Record 47 of Set 4 | mehamn
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | oistins
# City not found. Skipping...
# Processing Record 50 of Set 4 | sawtell
# Processing Record 51 of Set 4 | harper
# Processing Record 52 of Set 4 | nemuro
# Processing Record 53 of Set 4 | porangatu
# Processing Record 54 of Set 4 | pekan
# Processing Record 55 of Set 4 | xuanhua
# Processing Record 56 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 57 of Set 4 | katsiveli
# City not found. Skipping...
# Processing Record 58 of Set 4 | rodrigues alves
# Processing Record 59 of Set 4 | ewa beach
# Processing Record 60 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 61 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 62 of Set 4 | palagonia
# Processing Record 63 of Set 4 | viedma
# Processing Record 64 of Set 4 | mabaruma
# Processing Record 65 of Set 4 | vazhiny
# Processing Record 66 of Set 4 | antsohihy
# Processing Record 67 of Set 4 | aksu
# Processing Record 68 of Set 4 | bull savanna
# Processing Record 69 of Set 4 | avera
# Processing Record 70 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 71 of Set 4 | vanino
# Processing Record 72 of Set 4 | jitra
# Processing Record 73 of Set 4 | araouane
# Processing Record 74 of Set 4 | goundam
# Processing Record 75 of Set 4 | sar-e pul
# Processing Record 76 of Set 4 | saint anthony
# Processing Record 77 of Set 4 | bud
# Processing Record 78 of Set 4 | vostok
# Processing Record 79 of Set 4 | baykit
# Processing Record 80 of Set 4 | vestmannaeyjar
# Processing Record 81 of Set 4 | kutum
# Processing Record 82 of Set 4 | mahajanga
# Processing Record 83 of Set 4 | atar
# Processing Record 84 of Set 4 | jumla
# Processing Record 85 of Set 4 | arona
# Processing Record 86 of Set 4 | oxford
# Processing Record 87 of Set 4 | palmeira
# Processing Record 88 of Set 4 | mariana
# Processing Record 89 of Set 4 | te anau
# Processing Record 90 of Set 4 | kununurra
# Processing Record 91 of Set 4 | liezen
# Processing Record 92 of Set 4 | iralaya
# Processing Record 93 of Set 4 | santiago del estero
# Processing Record 94 of Set 4 | hovd
# Processing Record 95 of Set 4 | barranca
# Processing Record 96 of Set 4 | almeirim
# Processing Record 97 of Set 4 | unai
# Processing Record 98 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 99 of Set 4 | gornyak
# Processing Record 100 of Set 4 | kapuskasing
# Processing Record 1 of Set 5 | magadan
# Processing Record 2 of Set 5 | wonthaggi
# Processing Record 3 of Set 5 | rudnogorsk
# Processing Record 4 of Set 5 | champasak
# Processing Record 5 of Set 5 | inhambane
# Processing Record 6 of Set 5 | komsomolskoye
# Processing Record 7 of Set 5 | veraval
# Processing Record 8 of Set 5 | darhan
# Processing Record 9 of Set 5 | chabahar
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | itoman
# Processing Record 12 of Set 5 | pinerovka
# Processing Record 13 of Set 5 | darnah
# Processing Record 14 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 5 | sur
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | dobryanka
# Processing Record 18 of Set 5 | shima
# Processing Record 19 of Set 5 | melfort
# Processing Record 20 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 5 | solone
# Processing Record 22 of Set 5 | naze
# Processing Record 23 of Set 5 | suchedniow
# Processing Record 24 of Set 5 | eirunepe
# Processing Record 25 of Set 5 | burica
# City not found. Skipping...
# Processing Record 26 of Set 5 | conde
# Processing Record 27 of Set 5 | floro
# Processing Record 28 of Set 5 | grand gaube
# Processing Record 29 of Set 5 | stefan voda
# Processing Record 30 of Set 5 | luwingu
# Processing Record 31 of Set 5 | dahuk
# Processing Record 32 of Set 5 | bytow
# Processing Record 33 of Set 5 | oranjestad
# Processing Record 34 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 35 of Set 5 | kamien pomorski
# Processing Record 36 of Set 5 | yulara
# Processing Record 37 of Set 5 | olecko
# Processing Record 38 of Set 5 | pires do rio
# Processing Record 39 of Set 5 | bilgoraj
# Processing Record 40 of Set 5 | ornskoldsvik
# Processing Record 41 of Set 5 | dandong
# Processing Record 42 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 5 | talcahuano
# Processing Record 44 of Set 5 | omboue
# Processing Record 45 of Set 5 | morgan city
# Processing Record 46 of Set 5 | vrangel
# Processing Record 47 of Set 5 | port macquarie
# Processing Record 48 of Set 5 | thinadhoo
# Processing Record 49 of Set 5 | cravo norte
# Processing Record 50 of Set 5 | behshahr
# Processing Record 51 of Set 5 | san antonio
# Processing Record 52 of Set 5 | banjar
# Processing Record 53 of Set 5 | sape
# Processing Record 54 of Set 5 | muli
# Processing Record 55 of Set 5 | prince rupert
# Processing Record 56 of Set 5 | ust-nera
# Processing Record 57 of Set 5 | hamilton
# Processing Record 58 of Set 5 | cabedelo
# Processing Record 59 of Set 5 | le port
# Processing Record 60 of Set 5 | qabis
# City not found. Skipping...
# Processing Record 61 of Set 5 | zeya
# Processing Record 62 of Set 5 | ponta delgada
# Processing Record 63 of Set 5 | birao
# Processing Record 64 of Set 5 | alice springs
# Processing Record 65 of Set 5 | san cristobal
# Processing Record 66 of Set 5 | college
# Processing Record 67 of Set 5 | donskoye
# Processing Record 68 of Set 5 | polva
# Processing Record 69 of Set 5 | san ramon
# Processing Record 70 of Set 5 | salalah
# Processing Record 71 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 72 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 73 of Set 5 | seidu
# Processing Record 74 of Set 5 | zhanaozen
# Processing Record 75 of Set 5 | alyangula
# Processing Record 76 of Set 5 | praia da vitoria
# Processing Record 77 of Set 5 | montanha
# Processing Record 78 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 79 of Set 5 | emmett
# Processing Record 80 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 81 of Set 5 | khoy
# Processing Record 82 of Set 5 | evensk
# Processing Record 83 of Set 5 | sumbe
# Processing Record 84 of Set 5 | cayeli
# Processing Record 85 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 86 of Set 5 | kisangani
# Processing Record 87 of Set 5 | bafq
# Processing Record 88 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 89 of Set 5 | codajas
# Processing Record 90 of Set 5 | calama
# Processing Record 91 of Set 5 | loharu
# Processing Record 92 of Set 5 | suntar
# Processing Record 93 of Set 5 | quatre cocos
# Processing Record 94 of Set 5 | uzventis
# Processing Record 95 of Set 5 | gat
# Processing Record 96 of Set 5 | liepaja
# Processing Record 97 of Set 5 | tocopilla
# Processing Record 98 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 99 of Set 5 | kavaratti
# Processing Record 100 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | brae
# Processing Record 2 of Set 6 | vrises
# Processing Record 3 of Set 6 | durban
# Processing Record 4 of Set 6 | broome
# Processing Record 5 of Set 6 | lata
# Processing Record 6 of Set 6 | mahon
# Processing Record 7 of Set 6 | cody
# Processing Record 8 of Set 6 | gondanglegi
# Processing Record 9 of Set 6 | bacolod
# Processing Record 10 of Set 6 | sandnessjoen
# Processing Record 11 of Set 6 | barcelos
# Processing Record 12 of Set 6 | tir pol
# City not found. Skipping...
# Processing Record 13 of Set 6 | paka
# Processing Record 14 of Set 6 | somerset
# Processing Record 15 of Set 6 | ust-barguzin
# Processing Record 16 of Set 6 | orebro
# Processing Record 17 of Set 6 | verkhniy tagil
# Processing Record 18 of Set 6 | cortez
# Processing Record 19 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 6 | uray
# Processing Record 21 of Set 6 | ixtapa
# Processing Record 22 of Set 6 | ibotirama
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | sterling
# Processing Record 25 of Set 6 | tashla
# Processing Record 26 of Set 6 | las tunas
# Processing Record 27 of Set 6 | vila velha
# Processing Record 28 of Set 6 | heide
# Processing Record 29 of Set 6 | jhajjar
# Processing Record 30 of Set 6 | puerto carreno
# Processing Record 31 of Set 6 | sawakin
# Processing Record 32 of Set 6 | mazyr
# Processing Record 33 of Set 6 | iskateley
# Processing Record 34 of Set 6 | mitsamiouli
# Processing Record 35 of Set 6 | eyl
# Processing Record 36 of Set 6 | coruripe
# Processing Record 37 of Set 6 | nova granada
# Processing Record 38 of Set 6 | knysna
# Processing Record 39 of Set 6 | seoul
# Processing Record 40 of Set 6 | sonoita
# Processing Record 41 of Set 6 | honiara
# Processing Record 42 of Set 6 | bonavista
# Processing Record 43 of Set 6 | baherden
# Processing Record 44 of Set 6 | pandan
# Processing Record 45 of Set 6 | suao
# City not found. Skipping...
# Processing Record 46 of Set 6 | trairi
# Processing Record 47 of Set 6 | sorland
# Processing Record 48 of Set 6 | kolondieba
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 51 of Set 6 | srandakan
# Processing Record 52 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 53 of Set 6 | kudahuvadhoo
# Processing Record 54 of Set 6 | george
# Processing Record 55 of Set 6 | victoria point
# Processing Record 56 of Set 6 | san rafael
# Processing Record 57 of Set 6 | gasa
# Processing Record 58 of Set 6 | moose factory
# Processing Record 59 of Set 6 | mandalgovi
# Processing Record 60 of Set 6 | udomlya
# Processing Record 61 of Set 6 | buin
# Processing Record 62 of Set 6 | chernyshevskiy
# Processing Record 63 of Set 6 | rio grande
# Processing Record 64 of Set 6 | camabatela
# Processing Record 65 of Set 6 | bartica
# Processing Record 66 of Set 6 | ust-ilimsk
# Processing Record 67 of Set 6 | atherton
# Processing Record 68 of Set 6 | singleton
# Processing Record 69 of Set 6 | port lincoln
# Processing Record 70 of Set 6 | mareeba
# Processing Record 71 of Set 6 | aguimes
# Processing Record 72 of Set 6 | deputatskiy
# Processing Record 73 of Set 6 | kirakira
# Processing Record 74 of Set 6 | lavrentiya
# Processing Record 75 of Set 6 | maltahohe
# Processing Record 76 of Set 6 | zabaykalsk
# Processing Record 77 of Set 6 | seymchan
# Processing Record 78 of Set 6 | porto seguro
# Processing Record 79 of Set 6 | mingyue
# Processing Record 80 of Set 6 | maragheh
# Processing Record 81 of Set 6 | shingu
# Processing Record 82 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 83 of Set 6 | berlevag
# Processing Record 84 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 85 of Set 6 | north bend
# Processing Record 86 of Set 6 | povenets
# Processing Record 87 of Set 6 | kuusamo
# Processing Record 88 of Set 6 | konstantinovka
# Processing Record 89 of Set 6 | broken hill
# Processing Record 90 of Set 6 | coari
# Processing Record 91 of Set 6 | pouembout
# Processing Record 92 of Set 6 | polessk
# Processing Record 93 of Set 6 | gumdag
# Processing Record 94 of Set 6 | dzilam gonzalez
# Processing Record 95 of Set 6 | kasongo-lunda
# Processing Record 96 of Set 6 | petatlan
# Processing Record 97 of Set 6 | paita
# Processing Record 98 of Set 6 | tongchuan
# Processing Record 99 of Set 6 | lidorikion
# City not found. Skipping...
# Processing Record 100 of Set 6 | iberia
# Processing Record 1 of Set 7 | huangyan
# Processing Record 2 of Set 7 | krasnyy chikoy
# Processing Record 3 of Set 7 | kunashak
# Processing Record 4 of Set 7 | kenai
# Processing Record 5 of Set 7 | sunbury
# Processing Record 6 of Set 7 | fort atkinson
# Processing Record 7 of Set 7 | zhuhai
# Processing Record 8 of Set 7 | namatanai
# Processing Record 9 of Set 7 | galesong
# Processing Record 10 of Set 7 | salamanca
# Processing Record 11 of Set 7 | gornopravdinsk
# Processing Record 12 of Set 7 | rajgarh
# Processing Record 13 of Set 7 | liverpool
# Processing Record 14 of Set 7 | nola
# Processing Record 15 of Set 7 | kemijarvi
# Processing Record 16 of Set 7 | oktyabrskoye
# Processing Record 17 of Set 7 | paciran
# Processing Record 18 of Set 7 | pontalina
# Processing Record 19 of Set 7 | chokurdakh
# Processing Record 20 of Set 7 | ikorodu
# Processing Record 21 of Set 7 | nurota
# Processing Record 22 of Set 7 | beaverlodge
# Processing Record 23 of Set 7 | grindavik
# Processing Record 24 of Set 7 | ibipeba
# Processing Record 25 of Set 7 | porto santo
# Processing Record 26 of Set 7 | shelburne
# Processing Record 27 of Set 7 | ichinohe
# Processing Record 28 of Set 7 | ambilobe
# Processing Record 29 of Set 7 | durgapur
# Processing Record 30 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 7 | tupiza
# Processing Record 32 of Set 7 | mwinilunga
# Processing Record 33 of Set 7 | laguna
# Processing Record 34 of Set 7 | mendeleyevsk
# Processing Record 35 of Set 7 | rincon
# Processing Record 36 of Set 7 | kingsland
# Processing Record 37 of Set 7 | moen
# Processing Record 38 of Set 7 | marsh harbour
# Processing Record 39 of Set 7 | yatou
# Processing Record 40 of Set 7 | killarney
# Processing Record 41 of Set 7 | tchibanga
# Processing Record 42 of Set 7 | ploemeur
# Processing Record 43 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 7 | paso de los toros
# Processing Record 45 of Set 7 | joensuu
# Processing Record 46 of Set 7 | waipawa
# Processing Record 47 of Set 7 | san marcos
# Processing Record 48 of Set 7 | maldonado
# Processing Record 49 of Set 7 | skotterud
# Processing Record 50 of Set 7 | zhigansk
# Processing Record 51 of Set 7 | elliot lake
# Processing Record 52 of Set 7 | carutapera
# Processing Record 53 of Set 7 | sivaki
# Processing Record 54 of Set 7 | fez
# Processing Record 55 of Set 7 | bubaque
# Processing Record 56 of Set 7 | sept-iles
# Processing Record 57 of Set 7 | puerto colombia
# Processing Record 58 of Set 7 | flinders
# Processing Record 59 of Set 7 | maroantsetra
# Processing Record 60 of Set 7 | dickinson
# Processing Record 61 of Set 7 | altay
# Processing Record 62 of Set 7 | sabzevar
# Processing Record 63 of Set 7 | lanzhou
# Processing Record 64 of Set 7 | atasu
# Processing Record 65 of Set 7 | san felipe
# Processing Record 66 of Set 7 | basoko
# Processing Record 67 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 68 of Set 7 | okha
# Processing Record 69 of Set 7 | zaragoza
# Processing Record 70 of Set 7 | dinard
# Processing Record 71 of Set 7 | sarh
# Processing Record 72 of Set 7 | moussoro
# Processing Record 73 of Set 7 | kupang
# Processing Record 74 of Set 7 | whitehorse
# Processing Record 75 of Set 7 | fairbanks
# Processing Record 76 of Set 7 | ballina
# Processing Record 77 of Set 7 | zyryanka
# Processing Record 78 of Set 7 | klaksvik
# Processing Record 79 of Set 7 | hami
# Processing Record 80 of Set 7 | dauriya
# Processing Record 81 of Set 7 | natal
# Processing Record 82 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 83 of Set 7 | maniitsoq
# Processing Record 84 of Set 7 | keetmanshoop
# Processing Record 85 of Set 7 | brazzaville
# Processing Record 86 of Set 7 | kiruna
# Processing Record 87 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 88 of Set 7 | massaguet
# Processing Record 89 of Set 7 | cururupu
# Processing Record 90 of Set 7 | bamiantong
# Processing Record 91 of Set 7 | santa cruz de tenerife
# Processing Record 92 of Set 7 | mecca
# Processing Record 93 of Set 7 | kurchum
# Processing Record 94 of Set 7 | olafsvik
# Processing Record 95 of Set 7 | tirschenreuth
# Processing Record 96 of Set 7 | uporovo
# Processing Record 97 of Set 7 | lopadea noua
# City not found. Skipping...
# Processing Record 98 of Set 7 | sheregesh
# Processing Record 99 of Set 7 | cabo rojo
# Processing Record 100 of Set 7 | saint-georges
# Processing Record 1 of Set 8 | pangai
# Processing Record 2 of Set 8 | waingapu
# Processing Record 3 of Set 8 | alofi
# Processing Record 4 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 8 | can tho
# Processing Record 6 of Set 8 | inyonga
# Processing Record 7 of Set 8 | yako
# Processing Record 8 of Set 8 | cape elizabeth
# City not found. Skipping...
# Processing Record 9 of Set 8 | gillette
# Processing Record 10 of Set 8 | srednekolymsk
# Processing Record 11 of Set 8 | sfantu gheorghe
# Processing Record 12 of Set 8 | komagane
# Processing Record 13 of Set 8 | high level
# Processing Record 14 of Set 8 | pulandian
# Processing Record 15 of Set 8 | boyolangu
# Processing Record 16 of Set 8 | san juan
# Processing Record 17 of Set 8 | san policarpo
# Processing Record 18 of Set 8 | victor harbor
# Processing Record 19 of Set 8 | la baule-escoublac
# Processing Record 20 of Set 8 | barreirinhas
# Processing Record 21 of Set 8 | lafiagi
# Processing Record 22 of Set 8 | pecos
# Processing Record 23 of Set 8 | douentza
# Processing Record 24 of Set 8 | madera
# Processing Record 25 of Set 8 | luanda
# Processing Record 26 of Set 8 | trento
# Processing Record 27 of Set 8 | gizo
# Processing Record 28 of Set 8 | pointe-noire
# Processing Record 29 of Set 8 | nizhnyaya tavda
# Processing Record 30 of Set 8 | salisbury
# Processing Record 31 of Set 8 | colac
# Processing Record 32 of Set 8 | jinxiang
# Processing Record 33 of Set 8 | whitianga
# Processing Record 34 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 8 | tres arroyos
# Processing Record 36 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 8 | vagur
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | seddon
# Processing Record 40 of Set 8 | akdepe
# Processing Record 41 of Set 8 | tupik
# Processing Record 42 of Set 8 | tawzar
# City not found. Skipping...
# Processing Record 43 of Set 8 | mizan teferi
# Processing Record 44 of Set 8 | northam
# Processing Record 45 of Set 8 | wad madani
# Processing Record 46 of Set 8 | nizwa
# Processing Record 47 of Set 8 | raudeberg
# Processing Record 48 of Set 8 | miles city
# Processing Record 49 of Set 8 | sao jose da coroa grande
# Processing Record 50 of Set 8 | laiagam
# City not found. Skipping...
# Processing Record 51 of Set 8 | sampit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Victoria  22.2855  114.1577     70.00        71          35
# 1      Vilyuysk  63.7553  121.6247    -51.02        75          55
# 2   Pangnirtung  66.1451  -65.7125     -4.13        81          95
# 3      Hermanus -34.4187   19.2345     80.01        59          11
# 4      Bengkulu  -3.8004  102.2655     80.64        76         100
# 5     Swan Hill -35.3378  143.5544     77.02        23           0
# 6   Kostomuksha  64.5710   30.5767     16.30        97         100
# 7         Pisco -13.7000  -76.2167     68.00        77           0
# 8        Castro -24.7911  -50.0119     64.99        96         100
# 9  Kruisfontein -34.0033   24.7314     82.99        50           0
#
#    Wind Speed Country Current Description
# 0        1.01      HK    scattered clouds
# 1        2.64      RU       broken clouds
# 2        2.17      CA     overcast clouds
# 3       10.00      ZA          few clouds
# 4        8.66      ID     overcast clouds
# 5        4.21      AU           clear sky
# 6        2.48      RU     overcast clouds
# 7        4.61      PE           clear sky
# 8        5.88      BR     overcast clouds
# 9        8.01      ZA           clear sky

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# Assign city data df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Victoria      HK  22.2855  114.1577     70.00        71          35
# 1      Vilyuysk      RU  63.7553  121.6247    -51.02        75          55
# 2   Pangnirtung      CA  66.1451  -65.7125     -4.13        81          95
# 3      Hermanus      ZA -34.4187   19.2345     80.01        59          11
# 4      Bengkulu      ID  -3.8004  102.2655     80.64        76         100
# 5     Swan Hill      AU -35.3378  143.5544     77.02        23           0
# 6   Kostomuksha      RU  64.5710   30.5767     16.30        97         100
# 7         Pisco      PE -13.7000  -76.2167     68.00        77           0
# 8        Castro      BR -24.7911  -50.0119     64.99        96         100
# 9  Kruisfontein      ZA -34.0033   24.7314     82.99        50           0
#
#    Wind Speed Current Description
# 0        1.01    scattered clouds
# 1        2.64       broken clouds
# 2        2.17     overcast clouds
# 3       10.00          few clouds
# 4        8.66     overcast clouds
# 5        4.21           clear sky
# 6        2.48     overcast clouds
# 7        4.61           clear sky
# 8        5.88     overcast clouds
# 9        8.01           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
